# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
# Reading the rules - tab-separated file
df = pd.read_csv('amie-FB15k237.txt', sep='\t', names=['Rule', 'Support', 'StandardConfidence', 'PCAConfidence', 'HeadCoverage', 'BodySize', 'PCABodySize', 'variable', 'c2', 'c3', 'c4'])
df = df.drop(columns=['c2', 'c3', 'c4'])
print(df.head(1))
# Out:
#                                                                                                                                                                                                                       Rule  \
# 0  ?b  /organization/organization_member/member_of./organization/organization_membership/organization  ?a   => ?a  /government/political_party/politicians_in_this_party./government/political_party_tenure/politician  ?b
#
#     Support  StandardConfidence  PCAConfidence  HeadCoverage  BodySize  \
# 0  0.009346            0.001255          0.125             1       797
#
#    PCABodySize variable
# 0            8       ?b

# %%
# Distribution of each column
df.describe()
# Out:
#              Support  StandardConfidence  PCAConfidence   HeadCoverage  \
# count  222964.000000       222964.000000  222964.000000  222964.000000
# mean        0.031599            0.447096       0.598270      19.951230
# std         0.060128            0.298605       0.295957     147.436139
# min         0.000063            0.000022       0.100000       1.000000
# 25%         0.012262            0.180000       0.333333       3.000000
# 50%         0.017105            0.413043       0.600000       7.000000
# 75%         0.028947            0.684211       0.875000      14.000000
# max         1.000000            1.000000       1.000000   14032.000000
#
#             BodySize    PCABodySize
# count  222964.000000  222964.000000
# mean      117.940560      54.122688
# std      1167.543515     741.705844
# min         1.000000       1.000000
# 25%        10.000000       6.000000
# 50%        25.000000      16.000000
# 75%        47.000000      31.000000
# max    165293.000000   89649.000000

# %%
# unique values of column 'variable'
df['variable'].unique()
# Out:
# array(['?b', '?a'], dtype=object)

# %%
def rule_length(rule):
    # Split the rule by spaces to get components
    components = rule.split()
    return len(components)

# %%
df['rule_length'] = df['Rule'].apply(rule_length)
df['rule_length'].describe()
# Out:
# count    222964.000000
# mean          7.190847
# std           0.732203
# min           7.000000
# 25%           7.000000
# 50%           7.000000
# 75%           7.000000
# max          10.000000
# Name: rule_length, dtype: float64

# %%
df[df['rule_length'] > 7].head()
# Out:
#                                                                                                                                                                                                                                                                                       Rule  \
# 757          ?a  /government/political_party/politicians_in_this_party./government/political_party_tenure/politician  ?f  ?b  /influence/influence_node/influenced_by  ?f   => ?a  /government/political_party/politicians_in_this_party./government/political_party_tenure/politician  ?b
# 760                                ?f  /people/person/employment_history./business/employment_tenure/company  ?a  ?b  /people/person/spouse_s./people/marriage/spouse  ?f   => ?a  /government/political_party/politicians_in_this_party./government/political_party_tenure/politician  ?b
# 761  ?a  /government/political_party/politicians_in_this_party./government/political_party_tenure/politician  ?f  ?b  /people/person/spouse_s./people/marriage/spouse  ?f   => ?a  /government/political_party/politicians_in_this_party./government/political_party_tenure/politician  ?b
# 762                                ?e  /people/person/employment_history./business/employment_tenure/company  ?a  ?e  /people/person/spouse_s./people/marriage/spouse  ?b   => ?a  /government/political_party/politicians_in_this_party./government/political_party_tenure/politician  ?b
# 763  ?a  /government/political_party/politicians_in_this_party./government/political_party_tenure/politician  ?e  ?e  /people/person/spouse_s./people/marriage/spouse  ?b   => ?a  /government/political_party/politicians_in_this_party./government/political_party_tenure/politician  ?b
#
#       Support  StandardConfidence  PCAConfidence  HeadCoverage  BodySize  \
# 757  0.056075            0.157895           0.60             6        38
# 760  0.009346            0.041667           0.25             1        24
# 761  0.037383            0.400000           0.80             4        10
# 762  0.009346            0.040000           0.25             1        25
# 763  0.037383            0.400000           0.80             4        10
#
#      PCABodySize variable  rule_length
# 757           10       ?b           10
# 760            4       ?b           10
# 761            5       ?b           10
# 762            4       ?b           10
# 763            5       ?b           10

# %%
len(df[df['rule_length']>7])
# Out:
# 14184

# %%
df['Support'].describe()
# Out:
# count    222964.000000
# mean          0.031599
# std           0.060128
# min           0.000063
# 25%           0.012262
# 50%           0.017105
# 75%           0.028947
# max           1.000000
# Name: Support, dtype: float64

# %%
percentile_85_support = df['Support'].quantile(0.85)
percentile_85_support
# Out:
# 0.041189931

# %%
df['StandardConfidence'].describe()
# Out:
# count    222964.000000
# mean          0.447096
# std           0.298605
# min           0.000022
# 25%           0.180000
# 50%           0.413043
# 75%           0.684211
# max           1.000000
# Name: StandardConfidence, dtype: float64

# %%
percentile_85_confidence = df['StandardConfidence'].quantile(0.85)
percentile_85_confidence
# Out:
# 0.7938719002999988

# %%
filtered_df = df[(df['Support'] >= percentile_85_support) & (df['StandardConfidence'] >= percentile_85_confidence)]
filtered_df.describe()
# Out:
#            Support  StandardConfidence  PCAConfidence  HeadCoverage  \
# count  6314.000000         6314.000000    6314.000000   6314.000000
# mean      0.124935            0.864598       0.931126     53.421444
# std       0.129210            0.059092       0.075084    253.506914
# min       0.041190            0.793939       0.794118      4.000000
# 25%       0.058594            0.818182       0.857143     12.000000
# 50%       0.080537            0.847222       0.963189     21.000000
# 75%       0.142105            0.888889       1.000000     34.000000
# max       1.000000            1.000000       1.000000  12950.000000
#
#            BodySize   PCABodySize  rule_length
# count   6314.000000   6314.000000  6314.000000
# mean      61.585999     58.704941     7.210960
# std      302.134518    300.011568     0.767117
# min        4.000000      4.000000     7.000000
# 25%       13.000000     12.000000     7.000000
# 50%       24.000000     22.000000     7.000000
# 75%       41.000000     38.000000     7.000000
# max    15989.000000  15907.000000    10.000000

# %%
len(filtered_df[filtered_df['rule_length']>7])
# Out:
# 444

# %%
filtered_df.to_csv('output_rules.csv', index=False)

# %%
df['filtered'] = 0
df.loc[(df['Support'] >= percentile_85_support) & (df['StandardConfidence'] >= percentile_85_confidence), 'filtered'] = 1
df[df['filtered'] == 1].head(2)
# Out:
#                                                                                                                                                                     Rule  \
# 20  ?b  /sports/sports_team/roster./american_football/football_roster_position/position  ?a   => ?a  /sports/sports_position/players./sports/sports_team_roster/team  ?b
# 21           ?b  /sports/sports_team/roster./baseball/baseball_roster_position/position  ?a   => ?a  /sports/sports_position/players./sports/sports_team_roster/team  ?b
#
#      Support  StandardConfidence  PCAConfidence  HeadCoverage  BodySize  \
# 20  0.139143            0.802306       0.803630           487       607
# 21  0.042000            0.803279       0.803279           147       183
#
#     PCABodySize variable  rule_length  filtered
# 20          606       ?b            7         1
# 21          183       ?b            7         1

# %%
from sklearn.model_selection import train_test_split

# %%
stratify_col = filtered_df['rule_length']
df_train, df_sample = train_test_split(filtered_df, test_size=0.05, stratify=stratify_col, random_state=42)

df_sample.describe()
# Out:
#           Support  StandardConfidence  PCAConfidence  HeadCoverage  \
# count  316.000000          316.000000     316.000000    316.000000
# mean     0.131714            0.860714       0.929083     53.050633
# std      0.135489            0.056438       0.075495    164.521849
# min      0.041405            0.794118       0.794118      5.000000
# 25%      0.059061            0.818182       0.857143     11.750000
# 50%      0.083333            0.846154       0.943297     21.000000
# 75%      0.158025            0.888889       1.000000     34.000000
# max      1.000000            1.000000       1.000000   1833.000000
#
#           BodySize  PCABodySize  rule_length
# count   316.000000   316.000000   316.000000
# mean     61.063291    57.892405     7.208861
# std     187.905994   184.521572     0.764729
# min       5.000000     5.000000     7.000000
# 25%      13.000000    12.000000     7.000000
# 50%      24.000000    22.000000     7.000000
# 75%      41.000000    38.000000     7.000000
# max    2265.000000  2261.000000    10.000000

# %%
len(df_sample[df_sample['rule_length']>7])
# Out:
# 22

# %%
df_sample.head()
# Out:
#                                                                                                                                                                                                                                                               Rule  \
# 212609                                          /m/0gh65c5  /film/film/release_date_s./film/film_regional_release_date/film_release_region  ?a   => ?a  /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency  /m/09nqf
# 21405   /m/01zq91  /government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office  ?a   => ?a  /location/statistical_region/gni_per_capita_in_ppp_dollars./measurement_unit/dated_money_value/currency  /m/09nqf
# 138310                            ?a  /organization/organization_member/member_of./organization/organization_membership/organization  /m/0j7v_   => ?a  /organization/organization_member/member_of./organization/organization_membership/organization  /m/02vk52z
# 212554                                          /m/09gkx35  /film/film/release_date_s./film/film_regional_release_date/film_release_region  ?a   => ?a  /location/statistical_region/gdp_nominal_per_capita./measurement_unit/dated_money_value/currency  /m/09nqf
# 70291                                                                          /m/017gl1  /film/film/release_date_s./film/film_regional_release_date/film_release_region  ?a   => ?a  /base/aareas/schema/administrative_area/administrative_area_type  /m/0hzc9wc
#
#          Support  StandardConfidence  PCAConfidence  HeadCoverage  BodySize  \
# 212609  0.157895            0.810811       1.000000            30        37
# 21405   0.073826            0.916667       1.000000            11        12
# 138310  0.041405            0.804878       0.804878            33        41
# 212554  0.105263            0.869565       1.000000            20        23
# 70291   0.237179            0.840909       1.000000            37        44
#
#         PCABodySize variable  rule_length
# 212609           30       ?a            7
# 21405            11       ?a            7
# 138310           41       ?a            7
# 212554           20       ?a            7
# 70291            37       ?a            7

# %%
df_sample.to_csv('output_humaneval_rules.csv', index=False)

# %%
df['InSample'] = df.index.isin(df_sample.index).astype(int)
df[df['InSample'] == 1].head(2)
# Out:
#                                                                                                                                                                                                                                             Rule  \
# 447                                                                 ?a  /soccer/football_team/current_roster./soccer/football_roster_position/position  ?b   => ?a  /soccer/football_team/current_roster./sports/sports_team_roster/position  ?b
# 1148  ?e  /location/hud_county_place/place  ?b  ?a  /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony  ?e   => ?a  /people/marriage_union_type/unions_of_this_type./people/marriage/location_of_ceremony  ?b
#
#        Support  StandardConfidence  PCAConfidence  HeadCoverage  BodySize  \
# 447   0.810345            0.809272       0.810703          1833      2265
# 1148  0.215827            1.000000       1.000000            90        90
#
#       PCABodySize variable  rule_length  filtered  InSample
# 447          2261       ?a            7         1         1
# 1148           90       ?b           10         1         1

# %%
df.to_csv('updated_rules.csv', index=False)
